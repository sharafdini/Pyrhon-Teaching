# %%
Mellat-Leak
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a74363b4b05> in <module>
# ----> 1 Mellat-Leak
#
# NameError: name 'Mellat' is not defined

# %%
import pandas as pd

df3 = pd.read_csv("MO003.csv")
#df9 = pd.read_csv("MO009.csv", error_bad_lines=False)

#df.apply(lambda x: pd.lib.infer_dtype(x.values))

df.head(10)
# Out:
#    49******38  926****274   ميرسعيد             حسني     ميرحسن  4********8  \
# 0  42******32  561****974       علي       شايسته نيا     عليرضا        2**0
# 1  28******95    188**989  علي عسگر           خلخالي    گل محمد        1**1
# 2  14******86  876****025  محمدحسين  ميرزامحمدي كريق       عارف         5*1
# 3  00******49  398****621   حميدرضا         ابراهيمي  ابوالقاسم       2***4
# 4  64******77  830****862     طاهره      كاخكي جاغرق   غلامحسين         1*4
# 5  22******00  169****163     فرشيد            جوادي   امين اله         4*2
# 6  10******12  203****202  ابوالفضل        حسن آبادي   محمدحسين  1********2
# 7  03******04  436****361       علي   جعفري نيابهرام      جمشيد  0********4
# 8  23******05  317****961     ستاره             شيخي   علي مراد         2*9
# 9  20******11  931****280   ابراهيم           كمانگر  عبدالحسين         1*1
#
#    13******16              خوي     اذربايجان  غربي          چایپاره  \
# ...

# %%
df.filter(like='شرفدینی', axis=0)
# Out:
# Empty DataFrame
# Columns: [49******38, 926****274, ميرسعيد, حسني, ميرحسن, 4********8, 13******16, خوي, اذربايجان  غربي, چایپاره, آذربایجان غربی, *, 093*****871]
# Index: []

# %%
del df

# %%
l = [df3, df9]
df = pd.concat[l]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-99ad473ace77> in <module>
#       1 l = [df3, df9]
# ----> 2 df = pd.concat[l]
#
# TypeError: 'function' object is not subscriptable
